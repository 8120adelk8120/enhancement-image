# %%
import numpy as np
import cv2 as cv
from ultralytics import YOLO

# %%
model = YOLO('yolov8l.pt')

# %%
result = model('images1.jpg',show=True)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# image 1/1 C:\Users\koosha\Desktop\Car Plate Recognition\images1.jpg: 384x640 8 persons, 2 cars, 1341.9ms
# Speed: 43.0ms preprocess, 1341.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
